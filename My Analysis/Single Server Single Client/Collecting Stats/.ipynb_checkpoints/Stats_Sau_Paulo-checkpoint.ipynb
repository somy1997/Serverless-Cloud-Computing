# %%
import requests
import statistics
import random
import names
import string
import time
#import itertools #default zip() which doesn't require any imports behaves like itertools.izip() did in py2 so just use zip(), also, no module in itertools called izip in py3

# %%
# Generate data for n entries in the table in the file filename
# Email ID has a pattern
# First name and Last name are random
def gendata(n,filename) :
    f = open(filename, 'w')
    random.seed(7)
    for i in range(n):
        #firstname = ''.join(random.choices(string.ascii_uppercase, k=random.randrange(2,18)))
        #lastname = ''.join(random.choices(string.ascii_uppercase, k=random.randrange(2,18)))
        firstname = names.get_first_name()
        lastname = names.get_last_name()
        line = "custid%03d@iitkgp.ac.in,%s,%s\n"%(i, firstname, lastname)
        f.write(line)
    f.close()

# %%
def loaddata(filename) :
    f = open(filename, 'r')
    datalist = []
    for line in f:
        datalist += [tuple(line.strip().split(','))]
        #print(datalist[-1])
    f.close()
    return datalist

# %%
def collectstatspost(datalist,baseurl):
    statslist = []
    i = 1
    for item in datalist :
        payload = {'EmailID':item[0], 'FirstName':item[1], 'LastName':item[2]}
        start = time.time()
        response=requests.post(baseurl,json=payload)
        end = time.time()
        print('%03d'%(i)+'. ','Time Taken :',str(end-start)+'s Response :',response.text,'for',item)
        statslist += [int(response.text.split('$')[-1])]
        i += 1
    return statslist

# %%
def collectstatsget(datalist,baseurl):
    statslist = []
    i = 1
    for item in datalist :
        start = time.time()
        response=requests.get(baseurl+'?EmailID='+item[0])
        end = time.time()
        print('%03d'%(i)+'. ','Time Taken :',str(end-start)+'s Response :',response.text)
        statslist += [int(response.text.split('$')[-1])]
        i += 1
    return statslist

# %%
def getbilledstats(filename):
    f = open(filename, 'r')
    statslist = []
    for line in f:
        print(line)
        line = line.split()
        #print(line)
        statslist += [round(float(line[4]))] 
        #round function returns type as int by default (decimal places to keep is 0) otherwise float
    f.close()
    return statslist

# %%
def savestats(filename, actualstats, billedstats) :
    f = open(filename, 'w')
    f.write('Actual Time (ms),Billed Time (ms)\n')
    for (actualtime, billedtime) in zip(actualstats,billedstats):
        f.write("%d,%d\n"%(actualtime,billedtime))
    f.close()

# %%
#def getstats():
gendata(101, "data.txt")

# %%
datalist = loaddata("data.txt")
datalist
# Out:
# [('custid000@iitkgp.ac.in', 'Felisha', 'Vazquez'),
#  ('custid001@iitkgp.ac.in', 'John', 'Dickens'),
#  ('custid002@iitkgp.ac.in', 'Gail', 'Bohringer'),
#  ('custid003@iitkgp.ac.in', 'John', 'Landry'),
#  ('custid004@iitkgp.ac.in', 'Joseph', 'Metz'),
#  ('custid005@iitkgp.ac.in', 'Arnold', 'Scott'),
#  ('custid006@iitkgp.ac.in', 'Phillip', 'Russ'),
#  ('custid007@iitkgp.ac.in', 'Benjamin', 'Wolf'),
#  ('custid008@iitkgp.ac.in', 'John', 'Traverso'),
#  ('custid009@iitkgp.ac.in', 'Jane', 'Sylvester'),
#  ('custid010@iitkgp.ac.in', 'Debbie', 'Obryan'),
#  ('custid011@iitkgp.ac.in', 'Brandon', 'Wilbanks'),
#  ('custid012@iitkgp.ac.in', 'Susan', 'Birdsong'),
#  ('custid013@iitkgp.ac.in', 'Russell', 'Webber'),
#  ('custid014@iitkgp.ac.in', 'Bridget', 'Frye'),
#  ('custid015@iitkgp.ac.in', 'Jean', 'Black'),
#  ('custid016@iitkgp.ac.in', 'Travis', 'Gordon'),
#  ('custid017@iitkgp.ac.in', 'Thelma', 'Domina'),
#  ('custid018@iitkgp.ac.in', 'Amanda', 'Weltha'),
#  ('custid019@iitkgp.ac.in', 'Carl', 'Bailey'),
#  ('custid020@iitkgp.ac.in', 'Helen', 'Covington'),
#  ('custid021@iitkgp.ac.in', 'Gerry', 'Harris'),
#  ('custid022@iitkgp.ac.in', 'Heather', 'Manning'),
#  ('custid023@iitkgp.ac.in', 'Suzanne', 'Melendez'),
#  ('custid024@iitkgp.ac.in', 'Freddy', 'Madden'),
#  ('custid025@iitkgp.ac.in', 'John', 'Mitchel'),
#  ('custid026@iitkgp.ac.in', 'Debra', 'Cortez'),
#  ('custid027@iitkgp.ac.in', 'Mary', 'Ferrell'),
#  ('custid028@iitkgp.ac.in', 'Howard', 'Lugo'),
#  ('custid029@iitkgp.ac.in', 'Jerome', 'Baker'),
#  ('custid030@iitkgp.ac.in', 'Gary', 'Pagliaro'),
#  ('custid031@iitkgp.ac.in', 'Jennifer', 'Mcintyre'),
#  ('custid032@iitkgp.ac.in', 'Penelope', 'Dam'),
#  ('custid033@iitkgp.ac.in', 'Lena', 'Jennins'),
#  ('custid034@iitkgp.ac.in', 'Jeraldine', 'Collins'),
#  ('custid035@iitkgp.ac.in', 'William', 'Menendez'),
#  ('custid036@iitkgp.ac.in', 'Walter', 'Altman'),
#  ('custid037@iitkgp.ac.in', 'Debra', 'Campbell'),
#  ('custid038@iitkgp.ac.in', 'Audrey', 'Shelton'),
#  ('custid039@iitkgp.ac.in', 'Marvin', 'Poe'),
#  ('custid040@iitkgp.ac.in', 'Andrew', 'Kolbe'),
#  ('custid041@iitkgp.ac.in', 'Christina', 'Ayala'),
#  ('custid042@iitkgp.ac.in', 'Jeanette', 'Taylor'),
#  ('custid043@iitkgp.ac.in', 'Rosendo', 'Woodward'),
#  ('custid044@iitkgp.ac.in', 'Edward', 'Wilson'),
#  ('custid045@iitkgp.ac.in', 'Lawrence', 'Arellano'),
#  ('custid046@iitkgp.ac.in', 'Annette', 'Jackson'),
#  ('custid047@iitkgp.ac.in', 'Eugene', 'Evans'),
#  ('custid048@iitkgp.ac.in', 'Agustina', 'Wellman'),
#  ('custid049@iitkgp.ac.in', 'Lisa', 'Mcanulty'),
#  ('custid050@iitkgp.ac.in', 'Peggy', 'Hopkins'),
#  ('custid051@iitkgp.ac.in', 'Robert', 'Valdez'),
#  ('custid052@iitkgp.ac.in', 'Robin', 'Tallent'),
#  ('custid053@iitkgp.ac.in', 'Richard', 'Alo'),
#  ('custid054@iitkgp.ac.in', 'Betty', 'Zavala'),
#  ('custid055@iitkgp.ac.in', 'Jon', 'Fuller'),
#  ('custid056@iitkgp.ac.in', 'Jeffery', 'Matthews'),
#  ('custid057@iitkgp.ac.in', 'Deann', 'Walton'),
#  ('custid058@iitkgp.ac.in', 'Jack', 'Heise'),
#  ('custid059@iitkgp.ac.in', 'Katie', 'Bales'),
#  ('custid060@iitkgp.ac.in', 'Marc', 'Petrick'),
#  ('custid061@iitkgp.ac.in', 'Richard', 'Mccann'),
#  ('custid062@iitkgp.ac.in', 'Damion', 'Bjork'),
#  ('custid063@iitkgp.ac.in', 'Rebecca', 'Brody'),
#  ('custid064@iitkgp.ac.in', 'Wanda', 'Chiquito'),
#  ('custid065@iitkgp.ac.in', 'Cassidy', 'Osborne'),
#  ('custid066@iitkgp.ac.in', 'Robert', 'Bright'),
#  ('custid067@iitkgp.ac.in', 'Sarah', 'Hiatt'),
#  ('custid068@iitkgp.ac.in', 'Dennis', 'Trapp'),
#  ('custid069@iitkgp.ac.in', 'Jessie', 'Lopez'),
#  ('custid070@iitkgp.ac.in', 'Sheri', 'Demello'),
#  ('custid071@iitkgp.ac.in', 'Mallory', 'Durham'),
#  ('custid072@iitkgp.ac.in', 'Maria', 'Shaffstall'),
#  ('custid073@iitkgp.ac.in', 'Norma', 'Rathbun'),
#  ('custid074@iitkgp.ac.in', 'Edwin', 'Cox'),
#  ('custid075@iitkgp.ac.in', 'James', 'Peachey'),
#  ('custid076@iitkgp.ac.in', 'Eula', 'Campbell'),
#  ('custid077@iitkgp.ac.in', 'Ella', 'Cohen'),
#  ('custid078@iitkgp.ac.in', 'James', 'Antone'),
#  ('custid079@iitkgp.ac.in', 'Joe', 'Parizo'),
#  ('custid080@iitkgp.ac.in', 'Alita', 'Long'),
#  ('custid081@iitkgp.ac.in', 'James', 'Graham'),
#  ('custid082@iitkgp.ac.in', 'Leon', 'Hale'),
#  ('custid083@iitkgp.ac.in', 'Dorthy', 'Taylor'),
#  ('custid084@iitkgp.ac.in', 'Wendi', 'Loveless'),
#  ('custid085@iitkgp.ac.in', 'Alisha', 'Flatley'),
#  ('custid086@iitkgp.ac.in', 'Jack', 'Simons'),
#  ('custid087@iitkgp.ac.in', 'Eduardo', 'Ferree'),
#  ('custid088@iitkgp.ac.in', 'Gordon', 'Edwards'),
#  ('custid089@iitkgp.ac.in', 'Joshua', 'Niemi'),
#  ('custid090@iitkgp.ac.in', 'Kenneth', 'Jeffries'),
#  ('custid091@iitkgp.ac.in', 'Erma', 'Hall'),
#  ('custid092@iitkgp.ac.in', 'Thomas', 'Sims'),
#  ('custid093@iitkgp.ac.in', 'Henry', 'Wu'),
#  ('custid094@iitkgp.ac.in', 'Eric', 'Truong'),
#  ('custid095@iitkgp.ac.in', 'Vincent', 'Battle'),
#  ('custid096@iitkgp.ac.in', 'Grace', 'Hunt'),
#  ('custid097@iitkgp.ac.in', 'Kira', 'Bonneville'),
#  ('custid098@iitkgp.ac.in', 'Tyrone', 'Mitchell'),
#  ('custid099@iitkgp.ac.in', 'Matthew', 'Lowe'),
#  ('custid100@iitkgp.ac.in', 'Jeffrey', 'Graham')]

# %%
baseurlpost = 'https://at4u030oh3.execute-api.sa-east-1.amazonaws.com/testmypost/hellomypost'
actualstatslistpost = collectstatspost(datalist,baseurlpost)
# Out:
# 001.  Time Taken : 1.9749250411987305s Response : {}$57 for ('custid000@iitkgp.ac.in', 'Felisha', 'Vazquez')
# 002.  Time Taken : 1.9748880863189697s Response : {}$48 for ('custid001@iitkgp.ac.in', 'John', 'Dickens')
# 003.  Time Taken : 2.026888847351074s Response : {}$74 for ('custid002@iitkgp.ac.in', 'Gail', 'Bohringer')
# 004.  Time Taken : 1.9258549213409424s Response : {}$51 for ('custid003@iitkgp.ac.in', 'John', 'Landry')
# 005.  Time Taken : 2.0250492095947266s Response : {}$61 for ('custid004@iitkgp.ac.in', 'Joseph', 'Metz')
# 006.  Time Taken : 2.00551700592041s Response : {}$58 for ('custid005@iitkgp.ac.in', 'Arnold', 'Scott')
# 007.  Time Taken : 1.9201300144195557s Response : {}$47 for ('custid006@iitkgp.ac.in', 'Phillip', 'Russ')
# 008.  Time Taken : 1.9794809818267822s Response : {}$74 for ('custid007@iitkgp.ac.in', 'Benjamin', 'Wolf')
# 009.  Time Taken : 1.8901219367980957s Response : {}$38 for ('custid008@iitkgp.ac.in', 'John', 'Traverso')
# 010.  Time Taken : 1.9828369617462158s Response : {}$52 for ('custid009@iitkgp.ac.in', 'Jane', 'Sylvester')
# 011.  Time Taken : 2.0074868202209473s Response : {}$23 for ('custid010@iitkgp.ac.in', 'Debbie', 'Obryan')
# 012.  Time Taken : 2.039350986480713s Response : {}$73 for ('custid011@iitkgp.ac.in', 'Brandon', 'Wilbanks')
# 013.  Time Taken : 2.027435064315796s Response : {}$47 for ('custid012@iitkgp.ac.in', 'Susan', 'Birdsong')
# 014.  Time Taken : 1.9652099609375s Response : {}$46 for ('custid013@iitkgp.ac.in', 'Russell', 'Webber')
# 015.  Time Taken : 2.1023569107055664s Response : {}$53 for ('custid014@iitkgp.ac.in', 'Bridget', 'Frye')
# 016.  Time Taken : 1.892240285873413s Response : {}$53 for ('custid015@iitkgp.ac.in', 'Jean', 'Black')
# 017.  Time Taken : 1.9046728610992432s Response : {}$60 for ('custid016@iitkgp.ac.in', 'Travis', 'Gordon')
# 018.  Time Taken : 3.110931873321533s Response : {}$53 for ('custid017@iitkgp.ac.in', 'Thelma', 'Domina')
# 019.  Time Taken : 1.99552583694458s Response : {}$40 for ('custid018@iitkgp.ac.in', 'Amanda', 'Weltha')
# 020.  Time Taken : 2.0266549587249756s Response : {}$76 for ('custid019@iitkgp.ac.in', 'Carl', 'Bailey')
# 021.  Time Taken : 1.9408528804779053s Response : {}$35 for ('custid020@iitkgp.ac.in', 'Helen', 'Covington')
# 022.  Time Taken : 2.042711019515991s Response : {}$69 for ('custid021@iitkgp.ac.in', 'Gerry', 'Harris')
# 023.  Time Taken : 2.0566389560699463s Response : {}$43 for ('custid022@iitkgp.ac.in', 'Heather', 'Manning')
# 024.  Time Taken : 2.174849033355713s Response : {}$60 for ('custid023@iitkgp.ac.in', 'Suzanne', 'Melendez')
# 025.  Time Taken : 2.047321081161499s Response : {}$56 for ('custid024@iitkgp.ac.in', 'Freddy', 'Madden')
# 026.  Time Taken : 2.0626299381256104s Response : {}$70 for ('custid025@iitkgp.ac.in', 'John', 'Mitchel')
# 027.  Time Taken : 2.0286500453948975s Response : {}$43 for ('custid026@iitkgp.ac.in', 'Debra', 'Cortez')
# 028.  Time Taken : 1.9876165390014648s Response : {}$43 for ('custid027@iitkgp.ac.in', 'Mary', 'Ferrell')
# 029.  Time Taken : 1.967773199081421s Response : {}$51 for ('custid028@iitkgp.ac.in', 'Howard', 'Lugo')
# 030.  Time Taken : 2.0829379558563232s Response : {}$52 for ('custid029@iitkgp.ac.in', 'Jerome', 'Baker')
# 031.  Time Taken : 1.9865829944610596s Response : {}$56 for ('custid030@iitkgp.ac.in', 'Gary', 'Pagliaro')
# 032.  Time Taken : 2.103830099105835s Response : {}$36 for ('custid031@iitkgp.ac.in', 'Jennifer', 'Mcintyre')
# 033.  Time Taken : 2.0345218181610107s Response : {}$74 for ('custid032@iitkgp.ac.in', 'Penelope', 'Dam')
# 034.  Time Taken : 2.028282880783081s Response : {}$45 for ('custid033@iitkgp.ac.in', 'Lena', 'Jennins')
# 035.  Time Taken : 2.0688040256500244s Response : {}$104 for ('custid034@iitkgp.ac.in', 'Jeraldine', 'Collins')
# 036.  Time Taken : 2.005526065826416s Response : {}$48 for ('custid035@iitkgp.ac.in', 'William', 'Menendez')
# 037.  Time Taken : 1.9305579662322998s Response : {}$43 for ('custid036@iitkgp.ac.in', 'Walter', 'Altman')
# 038.  Time Taken : 2.056053876876831s Response : {}$33 for ('custid037@iitkgp.ac.in', 'Debra', 'Campbell')
# 039.  Time Taken : 1.9240357875823975s Response : {}$62 for ('custid038@iitkgp.ac.in', 'Audrey', 'Shelton')
# 040.  Time Taken : 1.9395332336425781s Response : {}$49 for ('custid039@iitkgp.ac.in', 'Marvin', 'Poe')
# 041.  Time Taken : 1.9790208339691162s Response : {}$47 for ('custid040@iitkgp.ac.in', 'Andrew', 'Kolbe')
# 042.  Time Taken : 2.0212671756744385s Response : {}$35 for ('custid041@iitkgp.ac.in', 'Christina', 'Ayala')
# 043.  Time Taken : 2.0511510372161865s Response : {}$73 for ('custid042@iitkgp.ac.in', 'Jeanette', 'Taylor')
# 044.  Time Taken : 1.9964196681976318s Response : {}$51 for ('custid043@iitkgp.ac.in', 'Rosendo', 'Woodward')
# 045.  Time Taken : 1.9983210563659668s Response : {}$73 for ('custid044@iitkgp.ac.in', 'Edward', 'Wilson')
# 046.  Time Taken : 2.0860629081726074s Response : {}$56 for ('custid045@iitkgp.ac.in', 'Lawrence', 'Arellano')
# 047.  Time Taken : 2.0077919960021973s Response : {}$47 for ('custid046@iitkgp.ac.in', 'Annette', 'Jackson')
# 048.  Time Taken : 2.1040236949920654s Response : {}$65 for ('custid047@iitkgp.ac.in', 'Eugene', 'Evans')
# 049.  Time Taken : 1.8955872058868408s Response : {}$36 for ('custid048@iitkgp.ac.in', 'Agustina', 'Wellman')
# 050.  Time Taken : 2.97505521774292s Response : {}$60 for ('custid049@iitkgp.ac.in', 'Lisa', 'Mcanulty')
# 051.  Time Taken : 2.10805606842041s Response : {}$104 for ('custid050@iitkgp.ac.in', 'Peggy', 'Hopkins')
# 052.  Time Taken : 2.018742084503174s Response : {}$39 for ('custid051@iitkgp.ac.in', 'Robert', 'Valdez')
# 053.  Time Taken : 2.003753900527954s Response : {}$65 for ('custid052@iitkgp.ac.in', 'Robin', 'Tallent')
# 054.  Time Taken : 1.9746477603912354s Response : {}$40 for ('custid053@iitkgp.ac.in', 'Richard', 'Alo')
# 055.  Time Taken : 2.042891025543213s Response : {}$78 for ('custid054@iitkgp.ac.in', 'Betty', 'Zavala')
# 056.  Time Taken : 1.9725611209869385s Response : {}$64 for ('custid055@iitkgp.ac.in', 'Jon', 'Fuller')
# 057.  Time Taken : 1.9617242813110352s Response : {}$57 for ('custid056@iitkgp.ac.in', 'Jeffery', 'Matthews')
# 058.  Time Taken : 2.0281660556793213s Response : {}$69 for ('custid057@iitkgp.ac.in', 'Deann', 'Walton')
# 059.  Time Taken : 1.967900037765503s Response : {}$59 for ('custid058@iitkgp.ac.in', 'Jack', 'Heise')
# 060.  Time Taken : 1.944580078125s Response : {}$27 for ('custid059@iitkgp.ac.in', 'Katie', 'Bales')
# 061.  Time Taken : 2.0613749027252197s Response : {}$65 for ('custid060@iitkgp.ac.in', 'Marc', 'Petrick')
# 062.  Time Taken : 1.9816350936889648s Response : {}$44 for ('custid061@iitkgp.ac.in', 'Richard', 'Mccann')
# 063.  Time Taken : 1.9594018459320068s Response : {}$70 for ('custid062@iitkgp.ac.in', 'Damion', 'Bjork')
# 064.  Time Taken : 2.0281810760498047s Response : {}$55 for ('custid063@iitkgp.ac.in', 'Rebecca', 'Brody')
# 065.  Time Taken : 1.9438319206237793s Response : {}$45 for ('custid064@iitkgp.ac.in', 'Wanda', 'Chiquito')
# 066.  Time Taken : 2.0340518951416016s Response : {}$69 for ('custid065@iitkgp.ac.in', 'Cassidy', 'Osborne')
# 067.  Time Taken : 1.9195911884307861s Response : {}$41 for ('custid066@iitkgp.ac.in', 'Robert', 'Bright')
# 068.  Time Taken : 1.9662790298461914s Response : {}$56 for ('custid067@iitkgp.ac.in', 'Sarah', 'Hiatt')
# 069.  Time Taken : 2.0848751068115234s Response : {}$77 for ('custid068@iitkgp.ac.in', 'Dennis', 'Trapp')
# 070.  Time Taken : 1.973870038986206s Response : {}$41 for ('custid069@iitkgp.ac.in', 'Jessie', 'Lopez')
# 071.  Time Taken : 1.927947998046875s Response : {}$51 for ('custid070@iitkgp.ac.in', 'Sheri', 'Demello')
# 072.  Time Taken : 1.9952988624572754s Response : {}$63 for ('custid071@iitkgp.ac.in', 'Mallory', 'Durham')
# 073.  Time Taken : 1.9361329078674316s Response : {}$39 for ('custid072@iitkgp.ac.in', 'Maria', 'Shaffstall')
# 074.  Time Taken : 1.9914889335632324s Response : {}$58 for ('custid073@iitkgp.ac.in', 'Norma', 'Rathbun')
# 075.  Time Taken : 1.9829888343811035s Response : {}$70 for ('custid074@iitkgp.ac.in', 'Edwin', 'Cox')
# 076.  Time Taken : 1.9895381927490234s Response : {}$89 for ('custid075@iitkgp.ac.in', 'James', 'Peachey')
# 077.  Time Taken : 1.9080419540405273s Response : {}$34 for ('custid076@iitkgp.ac.in', 'Eula', 'Campbell')
# 078.  Time Taken : 2.1706278324127197s Response : {}$52 for ('custid077@iitkgp.ac.in', 'Ella', 'Cohen')
# 079.  Time Taken : 1.9412500858306885s Response : {}$63 for ('custid078@iitkgp.ac.in', 'James', 'Antone')
# 080.  Time Taken : 1.9477381706237793s Response : {}$76 for ('custid079@iitkgp.ac.in', 'Joe', 'Parizo')
# 081.  Time Taken : 2.0438599586486816s Response : {}$74 for ('custid080@iitkgp.ac.in', 'Alita', 'Long')
# 082.  Time Taken : 2.014425039291382s Response : {}$60 for ('custid081@iitkgp.ac.in', 'James', 'Graham')
# 083.  Time Taken : 1.9650239944458008s Response : {}$51 for ('custid082@iitkgp.ac.in', 'Leon', 'Hale')
# 084.  Time Taken : 2.063013792037964s Response : {}$73 for ('custid083@iitkgp.ac.in', 'Dorthy', 'Taylor')
# 085.  Time Taken : 2.0394020080566406s Response : {}$56 for ('custid084@iitkgp.ac.in', 'Wendi', 'Loveless')
# 086.  Time Taken : 2.0206170082092285s Response : {}$67 for ('custid085@iitkgp.ac.in', 'Alisha', 'Flatley')
# 087.  Time Taken : 1.9538638591766357s Response : {}$62 for ('custid086@iitkgp.ac.in', 'Jack', 'Simons')
# 088.  Time Taken : 2.021975040435791s Response : {}$56 for ('custid087@iitkgp.ac.in', 'Eduardo', 'Ferree')
# 089.  Time Taken : 1.935971975326538s Response : {}$47 for ('custid088@iitkgp.ac.in', 'Gordon', 'Edwards')
# 090.  Time Taken : 1.9894599914550781s Response : {}$55 for ('custid089@iitkgp.ac.in', 'Joshua', 'Niemi')
# 091.  Time Taken : 2.0165817737579346s Response : {}$77 for ('custid090@iitkgp.ac.in', 'Kenneth', 'Jeffries')
# 092.  Time Taken : 2.093606948852539s Response : {}$59 for ('custid091@iitkgp.ac.in', 'Erma', 'Hall')
# 093.  Time Taken : 1.9773149490356445s Response : {}$68 for ('custid092@iitkgp.ac.in', 'Thomas', 'Sims')
# 094.  Time Taken : 1.9564440250396729s Response : {}$44 for ('custid093@iitkgp.ac.in', 'Henry', 'Wu')
# 095.  Time Taken : 2.159294366836548s Response : {}$78 for ('custid094@iitkgp.ac.in', 'Eric', 'Truong')
# 096.  Time Taken : 1.928379774093628s Response : {}$55 for ('custid095@iitkgp.ac.in', 'Vincent', 'Battle')
# 097.  Time Taken : 2.0382347106933594s Response : {}$57 for ('custid096@iitkgp.ac.in', 'Grace', 'Hunt')
# 098.  Time Taken : 2.0884337425231934s Response : {}$51 for ('custid097@iitkgp.ac.in', 'Kira', 'Bonneville')
# 099.  Time Taken : 1.987964153289795s Response : {}$61 for ('custid098@iitkgp.ac.in', 'Tyrone', 'Mitchell')
# 100.  Time Taken : 2.006765127182007s Response : {}$34 for ('custid099@iitkgp.ac.in', 'Matthew', 'Lowe')
# 101.  Time Taken : 2.095757007598877s Response : {}$51 for ('custid100@iitkgp.ac.in', 'Jeffrey', 'Graham')

# %%
# Copy logs in the following file before running this cell
billedlogsfilepost = 'cwlogs/sau_paulo_post.txt'
billedstatslistpost = getbilledstats(billedlogsfilepost)
savestatsfilepost = 'stats/sau_paulo_post.csv'
savestats(savestatsfilepost,actualstatslistpost,billedstatslistpost)
# Out:
# REPORT RequestId: 912b04eb-ff7d-4a8b-a532-56d93ec8542e	Duration: 979.22 ms	Billed Duration: 1000 ms Memory Size: 128 MB	Max Memory Used: 93 MB
#
# REPORT RequestId:
ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 101 MB
#
# REPORT RequestId: 94122239-b6a7-4c19-9055-6420eea71385	Duration: 79.47 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 101 MB
#
# REPORT RequestId: 79adcd88-1632-4541-be5d-86b645f5d988	Duration: 107.36 ms	Billed Duration: 200 ms Memory Size: 128 MB	Max Memory Used: 101 MB
#
# REPORT RequestId: d6e1f2a4-5865-421d-9daf-516a4b2b26f7	Duration: 75.26 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 101 MB
#
# REPORT RequestId: f379584f-6eb0-4e2f-bd8e-f079cabc27a1	Duration: 91.85 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 101 MB
#
# REPORT RequestId: f51bda05-55d0-487b-acf6-39b9e6015431	Duration: 73.56 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 101 MB
#
# REPORT RequestId: f32d4891-d719-41b6-af26-6395e26f2427	Duration: 65.76 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 101 MB
#
# REPORT RequestId: a09f704b-ebad-4d5f-bd80-72c4f0ae5ac7	Duration: 71.80 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 101 MB
#
# REPORT RequestId: ff38be08-3ab3-4e1a-b13a-f6a4971bb49a	Duration: 151.43 ms	Billed Duration: 200 ms Memory Size: 128 MB	Max Memory Used: 101 MB
#
# REPORT RequestId: d5bb9e4e-9489-4d76-b5a6-b865c6a194f0	Duration: 124.92 ms	Billed Duration: 200 ms Memory Size: 128 MB	Max Memory Used: 101 MB
#
# REPORT RequestId: 84b0e847-1608-4fc2-bbb9-2e17d2ed8f63	Duration: 59.48 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 101 MB
#
# REPORT RequestId: 15c7036f-3b1b-40ed-918f-bec4ca30ef2c	Duration: 76.16 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 101 MB
#
# REPORT RequestId: cf89113a-9213-4cdd-8af1-c07cafd09c5a	Duration: 69.15 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 101 MB
#
# REPORT RequestId: 9431c3ce-587d-4dcd-bc04-1e32ba4dde55	Duration: 78.66 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 101 MB
#
# REPORT RequestId: 2728a8b7-0ef5-4d4b-9a10-ee3c4bb1b0b2	Duration: 64.53 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 101 MB
#
# REPORT RequestId: e8764aa1-b27b-4488-b1c1-4bd4d88a8129	Duration: 84.33 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 101 MB
#
# REPORT RequestId: 932f5cbb-305a-4641-92b8-8b2e91c62ff5	Duration: 130.71 ms	Billed Duration: 200 ms Memory Size: 128 MB	Max Memory Used: 101 MB
#
# REPORT RequestId: c59ff80e-a2b6-492c-b534-5bd99bc5831c	Duration: 129.72 ms	Billed Duration: 200 ms Memory Size: 128 MB	Max Memory Used: 101 MB
#
# REPORT RequestId: 9dfdae48-fce6-46cb-bce9-b6077fd0fa39	Duration: 164.21 ms	Billed Duration: 200 ms Memory Size: 128 MB	Max Memory Used: 102 MB
#
# REPORT RequestId: 07a8f04e-2005-492e-a085-50d64c994af6	Duration: 80.79 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 102 MB
#
# REPORT RequestId: 697a04f1-d4fe-4c07-9933-e34c738c1a35	Duration: 156.96 ms	Billed Duration: 200 ms Memory Size: 128 MB	Max Memory Used: 102 MB
#
# REPORT RequestId: f6fe3e34-b1f5-48ce-a0a2-f25c22b7195e	Duration: 97.78 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 102 MB
#
# REPORT RequestId: cb1a6b32-181f-4069-ad63-5c8ddb2ab0c0	Duration: 63.25 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 102 MB
#
# REPORT RequestId: 6f51404b-120f-4985-b78e-8b6fe13fc4c7	Duration: 90.45 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 102 MB
#
# REPORT RequestId: 04f2d360-fa69-4a30-b765-8ffaadfc35e0	Duration: 64.76 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 102 MB

# %%
baseurlget = 'https://at4u030oh3.execute-api.sa-east-1.amazonaws.com/testmyget/hellomyget'
actualstatslistget = collectstatsget(datalist,baseurlget)
# Out:
# 001.  Time Taken : 9.718467712402344s Response : {"Item":{"FirstName":"Felisha","EmailID":"custid000@iitkgp.ac.in","LastName":"Vazquez"}}$698
# 002.  Time Taken : 8.466307878494263s Response : {"Item":{"FirstName":"John","EmailID":"custid001@iitkgp.ac.in","LastName":"Dickens"}}$73
# 003.  Time Taken : 8.501865863800049s Response : {"Item":{"FirstName":"Gail","EmailID":"custid002@iitkgp.ac.in","LastName":"Bohringer"}}$46
# 004.  Time Taken : 8.529155731201172s Response : {"Item":{"FirstName":"John","EmailID":"custid003@iitkgp.ac.in","LastName":"Landry"}}$48
# 005.  Time Taken : 8.507426738739014s Response : {"Item":{"FirstName":"Joseph","EmailID":"custid004@iitkgp.ac.in","LastName":"Metz"}}$70
# 006.  Time Taken : 8.493582963943481s Response : {"Item":{"FirstName":"Arnold","EmailID":"custid005@iitkgp.ac.in","LastName":"Scott"}}$50
# 007.  Time Taken : 8.527276992797852s Response : {"Item":{"FirstName":"Phillip","EmailID":"custid006@iitkgp.ac.in","LastName":"Russ"}}$66
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-1f4cfc8e5e41> in <module>
#       1 baseurlget = 'https://at4u030oh3.execute-api.sa-east-1.amazonaws.com/testmyget/hellomyget'
# ----> 2 actualstatslistget = collectstatsget(datalist,baseurlget)
#
# <ipython-input-23-85f6dbda2753> in collectstatsget(datalist, baseurl)
#       4     for item in datalist :
#       5         start = time.time()
# ----> 6         response=requests.get(baseurl+'?EmailID='+item[0])
#       7         end = time.time()
#       8         print('%03d'%(i)+'. ','Time Taken :',str(end-start)+'s Response :',response.text)
#
# /usr/local/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /usr/local/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /usr/local/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/local/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/local/Cellar/python/3.7.2_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# /usr/local/Cellar/python/3.7.2_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# /usr/local/Cellar/python/3.7.2_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# /usr/local/Cellar/python/3.7.2_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/local/Cellar/python/3.7.2_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1050                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1051                   self.__class__)
# -> 1052             return self.read(nbytes, buffer)
#    1053         else:
#    1054             return super().recv_into(buffer, nbytes, flags)
#
# /usr/local/Cellar/python/3.7.2_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in read(self, len, buffer)
#     909         try:
#     910             if buffer is not None:
# --> 911                 return self._sslobj.read(len, buffer)
#     912             else:
#     913                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Copy logs in the following file before running this cell
billedlogsfileget = 'cwlogs/sau_paulo_get.txt'
billedstatslistget = getbilledstats(billedlogsfileget)
savestatsfileget = 'stats/sau_paulo_get.csv'
savestats(savestatsfileget,actualstatslistget,billedstatslistget)
# Out:
# REPORT RequestId: 089ed588-8d51-411d-b109-3e07cd476495	Duration: 933.38 ms	Billed Duration: 1000 ms Memory Size: 128 MB	Max Memory Used: 93 MB
#
# REPORT RequestId: 072c6e62-bba7-47fa-946b-36ffdcba22e6	Duration: 87.01 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 93 MB
#
# REPORT RequestId: 1201fcbb-69a1-4643-8228-93d0a9036be9	Duration: 80.08 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 93 MB
#
# REPORT RequestId: 43155126-387d-483a-b33b-353bb263d926	Duration: 94.21 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 93 MB
#
# REPORT RequestId: c7ad4551-0ea1-4c3b-8e94-61d791f34ee9	Duration: 47.04 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 93 MB
#
# REPORT RequestId: e630b35b-2099-4775-9be6-0693e7c864c5	Duration: 62.74 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 93 MB
#
# REPORT RequestId: 2c35825f-85bd-4afe-ba68-c19bb86b0654	Duration: 69.37 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 93 MB
#
# REPORT RequestId: ea8977b8-a77e-47a1-b4a9-48d1a6b762df	Duration: 65.44 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 93 MB
#
# REPORT RequestId: fdf45400-b494-4352-a1bb-c634c7ee5173	Duration: 70.25 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 93 MB
#
# REPORT RequestId: 185bb2ec-7fdb-4734-8453-e41fc8c186bf	Duration: 97.83 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 93 MB
#
# REPORT RequestId: cfddd453-3962-4c86-9795-4ccda44a1f4b	Duration: 63.89 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 93 MB
#
# REPORT RequestId: d6a04850-a1cb-49a5-a1dd-1a4a9a9c0ab3	Duration: 97.36 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 93 MB
#
# REPORT RequestId: 810af007-fcba-42ee-b7b4-4c698800ad89	Duration: 73.48 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 93 MB
#
# REPORT RequestId: 0457f476-8476-4d5b-847d-4e46241c0483	Duration: 88.41 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 94 MB
#
# REPORT RequestId: edbfb04f-3d5c-4a91-97a4-44e31a2dc2ef	Duration: 64.91 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 94 MB
#
# REPORT RequestId: 3da3bb89-ea9d-4aea-838b-5483aa16e7bc	Duration: 79.49 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 94 MB
#
# REPORT RequestId: 340f06d5-0921-4037-8a6f-6da39f957722	Duration: 64.68 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 94 MB
#
# REPORT RequestId: d9be9c2c-a83f-4c65-824d-607fca0bb574	Duration: 67.03 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 94 MB
#
# REPORT RequestId: 36efd095-ac9b-470c-99b0-e6e686c47335	Duration: 155.25 ms	Billed Duration: 200 ms Memory Size: 128 MB	Max Memory Used: 95 MB
#
# REPORT RequestId: f76d1f0c-4bbe-485b-a5c0-5932190a8e23	Duration: 70.44 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 95 MB
#
# REPORT RequestId: cbc6ccb0-74df-42e2-ac62-e309af847325	Duration: 85.29 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 95 MB
#
# REPORT RequestId: 5925a481-7b53-4c70-96fa-9ab97c540728	Duration: 86.16 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 95 MB
#
# REPORT RequestId: 0b706ec6-bc49-4569-af4a-dcbcfec288ae	Duration: 130.43 ms	Billed Duration: 200 ms Memory Size: 128 MB	Max Memory Used: 96 MB
#
# REPORT RequestId: d51d7c92-f803-489a-930f-4f67434c8aac	Duration: 67.24 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 96 MB
#
# REPORT RequestId: 09a45204-2fee-47dc-a222-b421950c9028	Duration: 62.37 ms	Billed Duration: 100 ms Memory Size: 128 MB	Max Memory Used: 96 MB
#
# REPORT RequestId